# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl
import seaborn as sns
import numpy as np
from   sklearn.preprocessing import PolynomialFeatures
# %matplotlib inline

# %%
df = pd.read_csv('glass.csv');
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
features = df.drop('Type', axis = 1);
y = df.Type;

# %%
sns.boxplot(y = features.RI,x = y);

# %%
fName = 'Na'
plt.figure(figsize=[20,10]);
plt.title(fName)
plt.subplot(121);
plt.hist(features[fName],label=y)
plt.subplot(122);
sns.boxplot(y = features[fName],x = y);

# %%
fName = 'Mg'
plt.figure(figsize=[20,10]);
plt.title(fName)
plt.subplot(121);
plt.hist(features[fName],label=y)
plt.subplot(122);
sns.boxplot(y = features[fName],x = y);

# %%
fName = 'Al'
plt.figure(figsize=[20,10]);
plt.title(fName)
plt.subplot(121);
plt.hist(features[fName],label=y)
plt.subplot(122);
sns.boxplot(y = features[fName],x = y);

# %%
fName = 'Si'
plt.figure(figsize=[20,10]);
plt.title(fName)
plt.subplot(121);
plt.hist(features[fName],label=y)
plt.subplot(122);
sns.boxplot(y = features[fName],x = y);

# %%
fName = 'K'
plt.figure(figsize=[20,10]);
plt.title(fName)
plt.subplot(121);
plt.hist(features[fName],label=y)
plt.subplot(122);
sns.boxplot(y = features[fName],x = y);

# %%
fName = 'Ca'
plt.figure(figsize=[20,10]);
plt.title(fName)
plt.subplot(121);
plt.hist(features[fName],label=y)
plt.subplot(122);
sns.boxplot(y = features[fName],x = y);

# %%
fName = 'Ba'
plt.figure(figsize=[20,10]);
plt.title(fName)
plt.subplot(121);
plt.hist(features[fName],label=y)
plt.subplot(122);
sns.boxplot(y = features[fName],x = y);

# %%
fName = 'Fe'
plt.figure(figsize=[20,10]);
plt.title(fName)
plt.subplot(121);
plt.hist(features[fName],label=y)
plt.subplot(122);
sns.boxplot(y = features[fName],x = y);

# %% [markdown]
# Железо - только 1,2 и 3
#
# Барий - только в 7
#
# Кальций - повышенная концентрация в 5 типе.
#
# Калий практически отсутствует в 6 типе.
#
# Концентрация натрия повышена в образцах 6 и 7
#
# Магний отсутствует в 7 типе. Много в 1,2,3
#
# Кремний - основной компонент стекла. Вряд ли по нему можно будет что-то выяснить.
#
# Таким образом, виды 5, 6 и 7 легко выделяются. Проверим это.

# %%
from sklearn import tree
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
features.drop('total',axis =1,inplace=True)

# %%
def fit(dataset):
    X = dataset.drop('Type', axis = 1);
    y = dataset.Type;
    X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.33, random_state=0);
    clf.fit(X_train,y_train);
    #print clf.predict(X_test)
    print 'Accuracy is',clf.score(X_test,y_test)
    print 'Feature importance';
    for key, val in zip (features.columns,clf.feature_importances_):
        print key, val

# %%
fit(df)
# Out:
# Accuracy is 0.619718309859
# Feature importance
# RI 0.085463827277
# Na 0.0449642112204
# Mg 0.192833158403
# Al 0.164872745036
# Si 0.100792884721
# K 0.0739403453689
# Ca 0.135406222697
# Ba 0.186475443836
# Fe 0.0152511614402

# %%
features['total'] = features.Na+features.Mg+features.Al+features.Si+features.K+features.Ca+features.Ba+features.Fe;
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  total
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0  99.82
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0  99.89
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0  99.78
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0  99.59
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0  99.83

# %%
X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.33, random_state=0);
clf.fit(X_train,y_train);
print clf.predict(X_test)
print clf.score(X_test,y_test)
for key, val in zip (features.columns,clf.feature_importances_):
    print key, val
# Out:
# [7 1 1 6 2 2 1 2 1 2 2 2 2 2 2 7 2 2 1 2 5 3 7 5 1 1 7 1 2 2 1 1 2 1 3 1 1
#  3 1 7 5 6 2 2 2 2 1 2 1 2 1 6 7 1 2 1 1 2 7 1 1 1 1 5 1 2 2 1 1 1 1]
# 0.661971830986
# RI 0.15111008578
# Na 0.0262567282272
# Mg 0.202186899899
# Al 0.174226486532
# Si 0.0568302996874
# K 0.0739403453689
# Ca 0.113722549228
# Ba 0.201726605276
# Fe 0.0

# %%
df2 = df.copy();
df2['total'] = df2.Na+df2.Mg+df2.Al+df2.Si+df2.K+df2.Ca+df2.Ba+df2.Fe;
for feature in df2.columns.drop(['RI','Type','Si','total']):
    # print feature
    df2[feature] = df2[feature]/(df2.total - df2.Si)

df2.head()
# Out:
#         RI        Na        Mg        Al     Si         K        Ca   Ba   Fe  \
# 0  1.52101  0.486448  0.160128  0.039230  71.78  0.002140  0.312054  0.0  0.0
# 1  1.51761  0.511414  0.132548  0.050074  72.73  0.017673  0.288292  0.0  0.0
# 2  1.51618  0.505039  0.132512  0.057484  72.99  0.014558  0.290407  0.0  0.0
# 3  1.51766  0.489622  0.136768  0.047813  72.61  0.021127  0.304670  0.0  0.0
# 4  1.51742  0.496075  0.135327  0.046355  73.08  0.020561  0.301682  0.0  0.0
#
#    Type  total
# 0     1  99.82
# 1     1  99.89
# 2     1  99.78
# 3     1  99.59
# 4     1  99.83

# %%
fit(df2)
# Out:
# Accuracy is 0.647887323944
# Feature importance
# RI 0.085463827277
# Na 0.0927140803988
# Mg 0.202186899899
# Al 0.204158459321
# Si 0.0474765581908
# K 0.0589285714286
# Ca 0.107344998208
# Ba 0.186475443836
# Fe 0.0152511614402

# %%
def fit2(dataset):
    X = dataset.drop('Type', axis = 1);
    y = dataset.Type;
    X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.33, random_state=0);
    plf = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False);
    X_train2 = plf.fit_transform(X_train);
    X_test2 = plf.transform(X_test)
    
    clf = tree.DecisionTreeClassifier(random_state = 42)
    clf.fit(X_train2,y_train);
    #print clf.predict(X_test)
    print 'Accuracy is',clf.score(X_test2,y_test)
    print 'Feature importance';
    for key, val in zip (plf.get_feature_names(),clf.feature_importances_):
        print key, val

# %%
def fit3(dataset):
    from sklearn.neighbors import KNeighborsClassifier
    X = dataset.drop('Type', axis = 1);
    y = dataset.Type;
    X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.33, random_state=0);
    plf = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False);
    X_train2 = plf.fit_transform(X_train);
    X_test2 = plf.transform(X_test)
    
    kNN = KNeighborsClassifier();
    #clf = kNN.DecisionTreeClassifier(random_state = 42)
    kNN.fit(X_train2,y_train);
    #print clf.predict(X_test)
    print 'Accuracy is',clf.score(X_test2,y_test)
    print 'Feature importance';
    for key, val in zip (plf.get_feature_names(),clf.feature_importances_):
        print key, val

# %%
fit2(df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-168-b58c3114630b> in <module>()
# ----> 1 fit2(df2)
#
# <ipython-input-167-a041a5fd85a3> in fit2(dataset)
#       9
#      10     kNN = KNeighborsClassifier();
# ---> 11     clf = kNN.DecisionTreeClassifier(random_state = 42)
#      12     clf.fit(X_train2,y_train);
#      13     #print clf.predict(X_test)
#
# AttributeError: 'KNeighborsClassifier' object has no attribute 'DecisionTreeClassifier'

# %%
fit(df2)
# Out:
# Accuracy is 0.647887323944
# Feature importance
# RI 0.0948175687736
# Na 0.0740065974056
# Mg 0.192833158403
# Al 0.160195874287
# Si 0.0961160139732
# K 0.0729591836735
# Ca 0.107344998208
# Ba 0.186475443836
# Fe 0.0152511614402
